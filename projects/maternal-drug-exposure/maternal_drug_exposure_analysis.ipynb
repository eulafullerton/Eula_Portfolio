# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import sqlite3
import re

# %% [markdown]
# # Load your Datasets

# %%
import pandas as pd

# Function to rename columns to be SQLite-friendly (replace spaces and hyphens with underscores)
def rename_columns(df):
    df.columns = df.columns.str.replace(' ', '_').str.replace('-', '_').str.lower()  # Convert column names to lowercase
    return df

# Function to convert all values in the DataFrame to lowercase
def lowercase_all_values(df):
    return df.applymap(lambda x: str(x).lower() if isinstance(x, str) else x)

# Function to modify values in 'condition' column in df4 (Table 4):
# Convert all values to lowercase, remove hyphens, and replace spaces with underscores
def modify_condition_column(df):
    df['condition'] = df['condition'].str.replace('-', '_').str.replace(' ', '_').str.lower()
    return df

# Function to print unique values of each column in the DataFrame
def print_unique_values(df):
    for column in df.columns:
        print(f"Unique values in column '{column}': {df[column].unique()}")

# Load datasets into Pandas DataFrames
df1 = pd.read_csv("df_total_cleaned.csv") 
df2 = pd.read_csv("table_0_final.csv")
df3 = pd.read_csv("final_pregnancy_drug_data.csv")
df4 = pd.read_csv("pregnancy_conditions_common_drugs.csv")

# Rename columns to be SQLite-friendly (lowercase column names) and lowercase all values
df1 = rename_columns(df1)
df2 = rename_columns(df2)
df3 = rename_columns(df3)
df4 = rename_columns(df4)

# Convert all values to lowercase in the DataFrames
df1 = lowercase_all_values(df1)
df2 = lowercase_all_values(df2)
df3 = lowercase_all_values(df3)
df4 = lowercase_all_values(df4)

# Modify 'condition' column in df4 (Table 4)
df4 = modify_condition_column(df4)

# Print the unique values for each DataFrame
print("Unique values in df1:")
print_unique_values(df1)
print("\nUnique values in df2:")
print_unique_values(df2)
print("\nUnique values in df3:")
print_unique_values(df3)
print("\nUnique values in df4:")
print_unique_values(df4)
# Out:
# Unique values in df1:
# Unique values in column 'notes': ['total']
# Unique values in column 'census_region': ['census region 2: midwest' 'census region 3: south'
#  'census region 4: west' 'census region 1: northeast']
# Unique values in column 'census_region_code': ['cens-r2' 'cens-r3' 'cens-r4' 'cens-r1']
# Unique values in column 'chlamydia': ['yes' 'unknown']
# Unique values in column 'cause_of_death': ['unknown']
# Unique values in column 'deaths': [143. 256.  71.  18.  46.  25. 129. 273. 462. 253. 228. 488. 924. 356.
#   16.  47.  74.  12.  27.  52.  21.  60. 103. 223.  86. 132. 267. 482.
#  162. 501. 807. 263.  14.  20.  64.  33. 220. 540. 696. 171.]
# Unique values in column 'births': [ 14093.  30595.  10300.   2029.   3280.   3151.  50851.  64914. 105341.
#   75345.  50171.  81230. 141878.  75141.   1025.   2740.   5689.   1494.
#    1764.   3100.   4031.   6309.   2063.   6580.   9438.  17906.   8879.
#   18064.  24997.  46520.  17191.  24231.  37587.  55358.  25205.   1053.
#    1928.   4898.   2353.  18684.  45140.  53564.  16753.]
# Unique values in column 'death_rate': ['10.15' '8.37' '6.89' '8.87 (unreliable)' '14.02' '7.93' '2.54' '4.21'
#  '4.39' '3.36' '4.54' '6.01' '6.51' '4.74' '15.61 (unreliable)' '17.15'
#  '13.01' '8.03 (unreliable)' '10.20 (unreliable)' '8.71' '12.90' '11.25'
#  '10.18' '9.12' '10.91' '12.45' '9.69' '7.31' '10.68' '10.36' '9.42'
#  '10.56' '13.33' '14.58' '10.43' '13.30 (unreliable)' '10.37' '13.07'
#  '11.77' '11.96' '12.99' '10.21']
# Unique values in column 'eclampsia': ['unknown' 'yes']
# Unique values in column 'gestational_diabetes': ['unknown' 'yes']
# Unique values in column 'gestational_hypertension': ['unknown' 'yes']
# Unique values in column 'gonorrhea': ['unknown' 'yes']
# Unique values in column 'hepatitis_b': ['unknown' 'yes']
# Unique values in column 'hepatitis_c': ['unknown' 'yes']
# Unique values in column 'pre_pregnancy_diabetes': ['unknown' 'yes']
# Unique values in column 'pre_pregnancy_hypertension': ['unknown' 'yes']
# Unique values in column 'previous_preterm_birth': ['unknown' 'yes']
# Unique values in column 'syphilis': ['unknown' 'yes']
# Unique values in column 'tobacco_use': ['unknown' 'yes']
#
# Unique values in df2:
# Unique values in column 'pregnancy_category': ['a' 'b' 'c' 'd' 'x' 'n']
# Unique values in column 'risk': ['no risk in controlled human studies' 'no risk in other studies'
#  'risk not ruled out' 'positive evidence of risk'
#  'contraindicated in pregnancy'
#  'the fda has not yet classified the drug into a specified pregnancy category.']
# Unique values in column 'detailed_description': [' adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).'
#  ' animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.'
#  ' animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.'
#  ' there is positive evidence of human fetal risk based on adverse reaction data from investigational or marketing experience or studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.'
#  ' studies in animals or humans have demonstrated fetal abnormalities and/or there is positive evidence of human fetal risk based on adverse reaction data from investigational or marketing experience, and the risks involved in use of the drug in pregnant women clearly outweigh potential benefits.'
#  nan]
#
# Unique values in df3:
# Unique values in column 'report_id': [10009044 10016807 10019262 10023714 10038823 10017067 10027891 10027954
#  10047438 10051068 10056773 10056780 10056787 10056791 10056792 10060198
#  10072649 10144772 10227619 10235084 10003326 10003424 10003428 10003429
#  10003449 10222287 10285328 10287488 10396427 10440328 10014483 10056932
#  10059489 10074379 10079120 10012150 10012151 10012212 10023077 10010087
#  10010162 10012752 10024207 10024410]
# Unique values in column 'patient_age': [ 1. nan 35.  0. 33. 39. 28. 32. 42. 29. 30. 19. 24. 18.  8. 23.  4.]
# Unique values in column 'patient_sex': [ 1.  0.  2. nan]
# Unique values in column 'patient_weight': [  4.      nan   2.54  68.     3.6  108.96  61.     2.5    2.6    3.2
#    0.8 ]
# Unique values in column 'drug_indication': ['hypertension, hypertension, gestational diabetes, prophylaxis of neural tube defect, hypertension, thrombosis prophylaxis'
#  nan 'gestational diabetes' 'diabetes mellitus'
#  'hiv infection, hiv infection, diabetes mellitus, diabetes mellitus'
#  'renal transplant, renal transplant, renal transplant, renal transplant, dyslipidaemia, hypertension, constipation, constipation, hypertension, constipation'
#  'pre-eclampsia, hypertension' 'contraception'
#  'labour induction, asthma, asthma, gestational hypertension, labour pain, anaemia, labour induction'
#  'threatened labour, threatened labour, threatened labour'
#  'intrapartum haemorrhage, polycystic ovaries, hypothyroidism, gestational diabetes, product used for unknown indication'
#  'pulmonary embolism, pregnancy, pregnancy' 'assisted fertilisation'
#  'listeriosis, listeriosis' 'listeriosis, listeriosis, listeriosis'
#  'listeriosis, listeriosis, listeriosis, listeriosis'
#  'product used for unknown indication, product used for unknown indication, pain, product used for unknown indication, product used for unknown indication, epidural analgesia, product used for unknown indication'
#  'streptococcus test positive'
#  'product used for unknown indication, product used for unknown indication, product used for unknown indication, streptococcal infection, sinus headache, product used for unknown indication'
#  'hiv infection, product used for unknown indication, product used for unknown indication, hiv infection, product used for unknown indication, hiv infection, product used for unknown indication, hiv infection, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication'
#  'postpartum depression, postpartum depression'
#  'typhoid fever, sepsis, sepsis' 'depression, mineral supplementation'
#  'hiv infection, hiv infection, hiv infection'
#  'maternal exposure timing unspecified, maternal exposure timing unspecified, maternal exposure timing unspecified'
#  'product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication, product used for unknown indication'
#  'drug dependence, nicotine dependence'
#  'drug dependence, product used for unknown indication, product used for unknown indication, nutritional supplementation, depression, depression, anxiety'
#  'drug dependence, drug dependence'
#  'drug dependence, drug dependence, product used for unknown indication, product used for unknown indication']
# Unique values in column 'seriousness_congenital_anomaly': [ 1. nan  2.]
# Unique values in column 'target_medicinal_product': ['insulin' 'insulin glargine' 'labetalol' 'labetalol, labetalol'
#  'magnesium sulfate' 'magnesium sulfate.' 'progesterone.' 'progesterone'
#  'progesterone (solution)' 'ceftriaxone' 'penicillin g'
#  'penicillin g potassium injection'
#  'penicillin g potassium injection, penicillin g potassium injection'
#  'azithromycin, azithromycin, lamivudine, lamivudine' 'azithromycin'
#  'ceftriaxone injection, azithromycin' 'lamivudine-hiv' 'lamivudine'
#  'lamivudine and zidovudine' 'nicotine' 'nicotine (none)']
# Unique values in column 'other_medicinal_product': ['metoprolol (unknown), bisoprolol, folio, dopegyt, ass'
#  'hydralazine, methyldopa, telmisartan, amlodipine, nifedipine, hydrocortisone, hydrocortisone sodium succinate, nicardipine'
#  'effexor, zyprexa, levothyrox' 'solostar, humalog'
#  'combivir, kaletra, metformin, nexium, prenatal vitamin'
#  'mycophenolate mofetil, calcitriol, azathioprine, prednisone, tacrolimus, atorvastatin, atorvastatin, metoprolol tartrate, metoprolol tartrate, norvasc, sodium bicarbonate, docusate, polyethylene glycol, imuran, amlodipine, famotidine, miralax'
#  'nifedipine, nifedipine'
#  'hydrochlorothiazide., triamcinolone, tylenol, tramadol, proair hfa, clonidine., mirena, promethazine w/codeine, phentermine, ibuprofen., propranolol'
#  'oxytocin, salbutamol, fluticasone, calcium, fentanyl, ropivacaine hydrochloride, ferrous sulfate, cervidil'
#  'heparin, ritodrine hydrochloride' 'uteron, betamethasone.'
#  'uteron, betamethasone., uteron' 'uteron, uteron, betamethasone.'
#  'glucophage, eltroxin, glucophage, clexane'
#  'armour thyroid, procardia, lovenox, aspirin, clomid'
#  'lovenox, estradiol, folic acid' 'bravelle, decapeptyl /00957902/'
#  'acetylsalicylic acid({=100 mg), procardia, lovenox, armour thyroid'
#  'metronidazole' 'metronidazole, amoxicillin'
#  'clarithromycin, amoxicillin+clavulanate, cefmetazole'
#  'ranitidine, entonox, paracetamol, piriton, levobupivacaine, nitrous oxide'
#  'usp' 'usp, usp'
#  'augmentin, effexor, venlafaxine hydrochloride tablets 25 mg, tylenol, amoxicillin sodium w/clavulanate potassium'
#  'isentress, isentress, isentress, abacavir, abacavir, abacavir, acyclovir, acyclovir, bactrim, bactrim, intelence, intelence, intelence, prezista, prezista, prezista, ritonavir, ritonavir, viread, viread, viread, viread, zidovudine, zidovudine, folic acid, iron, magnesium gluconate, iron;minerals nos;vitamins nos, calcium carbonate, calcium pantothenate, ergocalciferol, ferrous fumarate, nicotinamide, pyridoxine hydrochloride, vitamin a palmitate, riboflavin, thiamine mononitrate, vitamin b12, vitamin c'
#  'effexor, amox-clav, effexor, venlafaxine hcl, hydrocodone/apap, venlafaxine hcl, prenaplus, ibuprofen., proair inhaler, venlafaxine hcl, effexor, effexor xr, venlafaxine hcl, lithium., penicillin vk, effexor'
#  'venlafaxine, nitrofur mac, metronidazole., zantac, terbutaline, prenatal vitamins, effexor, fluoxetine, tylenol with codeine, meclizine, effexor xr, meclizine, neo/poly/hc, buspirone, flexeril, ofloxacin., hydroxyzine pam, vistaril'
#  'usp (in dextrose), zosyn'
#  'wellbutrin, wellbutrin xl, clarinex, naproxen., effexor, chlorhexidine, prednisone., venlafaxine hcl, iron, lunesta, permethrin., hydroxyzine, prenatabs, budeprion xl, necon, effexor, oxcarbazepine., bupropion, lamotrigine., trileptal, oxycodone w/ apap, ciprofloxacin., vitafol-ob dha, effexor xr, acetaminophen/cod, amoxicillin., folic acid., lamictal, prenatal vitamins, nitrofurantoin-macro, ibuprofen., prenatabs rx, folic acid., repliva'
#  'abacavir, kaletra' 'kaletra, abacavir'
#  'prezista, lexiva, zidovudine, norvir, viread' 'buprenorphine generic'
#  'suboxone film, alcohol, prenatal vitamins, zoloft, effexor, xanax'
#  'suboxone 8 mg' 'suboxone, subutex 8 mg, vitamins'
#  'suboxone 8 mg, buprenorphine 8 mg (none), unspecified ingredient']
# Unique values in column 'pregnancy_reaction_event': ['foetal exposure during pregnancy'
#  'foetal death, foetal heart rate deceleration abnormality, foetal exposure during pregnancy'
#  'ectopic pregnancy, exposure during pregnancy'
#  'maternal exposure during pregnancy, foetal death'
#  'premature delivery, exposure during pregnancy'
#  'premature delivery, pregnancy with contraceptive device'
#  'maternal exposure during pregnancy'
#  'foetal growth restriction, exposure during pregnancy'
#  'exposure during pregnancy' 'ectopic pregnancy'
#  'foetal death, maternal exposure during pregnancy'
#  'foetal distress syndrome, foetal exposure during pregnancy'
#  'exposure during pregnancy, foetal death'
#  'maternal exposure during pregnancy, persistent foetal circulation'
#  'foetal growth restriction, foetal exposure during pregnancy']
# Unique values in column 'other_reaction_event': ['congenital hydronephrosis, ureteric stenosis' 'premature baby'
#  'multiple congenital abnormalities' 'no therapeutic response'
#  'ventricular septal defect, atrial septal defect, congenital skin dimples, cardiac murmur'
#  nan
#  'neonatal respiratory distress syndrome, jaundice neonatal, premature baby'
#  'hypertension, proteinuria, umbilical cord vascular disorder'
#  'injury, device breakage, uterine perforation, emotional distress, abortion spontaneous, infertility female, device difficult to use, pain, drug ineffective'
#  'hypertension, renal failure chronic, condition aggravated, drug ineffective'
#  'premature baby, apgar score low, acidosis' 'pulmonary oedema'
#  'abortion spontaneous, off label use'
#  'oligohydramnios, breech presentation' 'thrombosis' 'oligohydramnios'
#  'meconium stain, amniotic cavity infection'
#  'abortion late, amniotic cavity infection'
#  'intraventricular haemorrhage neonatal, low birth weight baby, listeriosis, pyrexia, sepsis, meningitis, pneumonia aspiration, oxygen saturation decreased'
#  'pyelonephritis, normal newborn' 'angioedema, enlarged uvula, live birth'
#  'injection site pain' 'infusion site pain'
#  'burning sensation, infusion related reaction'
#  'double outlet right ventricle, pulmonary artery stenosis congenital, sepsis neonatal, feeding disorder neonatal, tricuspid valve incompetence, persistent left superior vena cava, cardiac failure congestive, failure to thrive, aortic valve stenosis, atelectasis, dysphagia, patent ductus arteriosus, phimosis, apnoea, neonatal respiratory distress syndrome, atrial septal defect, plagiocephaly, metabolic acidosis, chylothorax, torticollis, developmental delay, speech disorder developmental, premature baby, cardiomegaly, pulmonary oedema, supraventricular tachycardia, hypotonia, muscular weakness, fallot^s tetralogy, congenital coronary artery malformation, ventricular septal defect, genital rash, anaemia neonatal, fine motor delay, transposition of the great vessels, jaundice, pulmonary hypertension, gross motor delay, hepatomegaly, abnormal loss of weight, maternal drugs affecting foetus'
#  'anaemia, toxicity to various agents' 'anencephaly'
#  'congenital anomaly, meningomyelocele, talipes, arnold-chiari malformation, congenital hydrocephalus, premature baby'
#  'vaginal haemorrhage, abdominal pain lower'
#  'patent ductus arteriosus, tricuspid valve incompetence, atrial septal defect, congenital anomaly, congenital choroid plexus cyst, neonatal respiratory distress syndrome'
#  'dialysis, blood pressure inadequately controlled, blood glucose increased, chronic obstructive pulmonary disease, superior vena cava syndrome, treatment noncompliance, live birth, diabetes mellitus inadequate control'
#  'acute hepatic failure, renal failure acute, respiratory arrest, premature baby'
#  'premature baby, acute hepatic failure, renal failure acute, respiratory arrest, cardiomegaly, abdominal distension, pseudocyst, gastrointestinal disorder congenital, neural tube defect'
#  'micrognathia'
#  'wrong technique in drug usage process, abortion spontaneous'
#  'alcohol abuse, intentional underdose'
#  'drug withdrawal syndrome neonatal' 'selective abortion']
#
# Unique values in df4:
# Unique values in column 'condition': ['pre_pregnancy_diabetes' 'gestational_diabetes'
#  'pre_pregnancy_hypertension' 'gestational_hypertension' 'eclampsia'
#  'previous_preterm_birth' 'gonorrhea' 'syphilis' 'chlamydia' 'hepatitis_b'
#  'hepatitis_c' 'nicotine']
# Unique values in column 'number_one_drug_used': ['insulin' 'labetalol' 'magnesium sulfate' 'progesterone ' 'ceftriaxone'
#  'penicillin g' 'azithromycin' 'lamivudine'
#  'avoid treatment during pregnancy' 'nicotine']
# Unique values in column 'fda_pregnancy_risk_category': ['a' 'c' 'b' 'n' 'd']
# C:\Users\samue\AppData\Local\Temp\ipykernel_57432\4167467443.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: str(x).lower() if isinstance(x, str) else x)

# %% [markdown]
# # Create SQLite Database

# %%
# Connect to (or create) an SQLite database
conn = sqlite3.connect("pregnancy_database.db")
cursor = conn.cursor()

# %%
# Save the DataFrames as individual tables in the SQLite database
df1.to_sql("table1", conn, if_exists="replace", index=False)
df2.to_sql("table2", conn, if_exists="replace", index=False)
df3.to_sql("table3", conn, if_exists="replace", index=False)
df4.to_sql("table4", conn, if_exists="replace", index=False)

print("Datasets successfully loaded into SQLite.")
# Out:
# Datasets successfully loaded into SQLite.

# %%
# List all tables in the database
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print("Tables in the database:")
print(tables)
# Out:
# Tables in the database:
#      name
# 0  table1
# 1  table2
# 2  table3
# 3  table4

# %% [markdown]
# ## Inspect Data in SQLite

# %%
# Query to get all table names in the database
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables_df = pd.read_sql_query(tables_query, conn)

# Loop through each table and display the first 10 rows
for table_name in tables_df['name']:
    print(f"Inspecting table: {table_name}")
    
    # Query to select all data from the current table (limit to first 10 rows)
    query = f"SELECT * FROM {table_name} LIMIT 10;"
    df_table = pd.read_sql_query(query, conn)
    
    # Display the first few rows of the current table
    print(df_table.head())
    print("\n" + "-"*50 + "\n")
# Out:
# Inspecting table: table1
#    notes             census_region census_region_code chlamydia  \
# 0  total  census region 2: midwest            cens-r2       yes
# 1  total    census region 3: south            cens-r3       yes
# 2  total     census region 4: west            cens-r4       yes
# 3  total  census region 2: midwest            cens-r2   unknown
# 4  total    census region 3: south            cens-r3   unknown
#
#   cause_of_death  deaths   births         death_rate eclampsia  \
# 0        unknown   143.0  14093.0              10.15   unknown
# 1        unknown   256.0  30595.0               8.37   unknown
# 2        unknown    71.0  10300.0               6.89   unknown
# 3        unknown    18.0   2029.0  8.87 (unreliable)       yes
# 4        unknown    46.0   3280.0              14.02       yes
#
#   gestational_diabetes gestational_hypertension gonorrhea hepatitis_b  \
# 0              unknown                  unknown   unknown     unknown
# 1              unknown                  unknown   unknown     unknown
# 2              unknown                  unknown   unknown     unknown
# 3              unknown                  unknown   unknown     unknown
# 4              unknown                  unknown   unknown     unknown
#
#   hepatitis_c pre_pregnancy_diabetes pre_pregnancy_hypertension  \
# 0     unknown                unknown                    unknown
# 1     unknown                unknown                    unknown
# 2     unknown                unknown                    unknown
# 3     unknown                unknown                    unknown
# 4     unknown                unknown                    unknown
#
#   previous_preterm_birth syphilis tobacco_use
# 0                unknown  unknown     unknown
# 1                unknown  unknown     unknown
# 2                unknown  unknown     unknown
# 3                unknown  unknown     unknown
# 4                unknown  unknown     unknown
#
# --------------------------------------------------
#
# Inspecting table: table2
#   pregnancy_category                                 risk  \
# 0                  a  no risk in controlled human studies
# 1                  b             no risk in other studies
# 2                  c                   risk not ruled out
# 3                  d            positive evidence of risk
# 4                  x         contraindicated in pregnancy
#
#                                 detailed_description
# 0   adequate and well-controlled human studies ha...
# 1   animal reproduction studies have failed to de...
# 2   animal reproduction studies have shown an adv...
# 3   there is positive evidence of human fetal ris...
# 4   studies in animals or humans have demonstrate...
#
# --------------------------------------------------
#
# Inspecting table: table3
#    report_id  patient_age  patient_sex  patient_weight  \
# 0   10009044          1.0          1.0            4.00
# 1   10016807          NaN          0.0             NaN
# 2   10019262          NaN          2.0            2.54
# 3   10023714         35.0          2.0           68.00
# 4   10038823          0.0          2.0            3.60
#
#                                      drug_indication  \
# 0  hypertension, hypertension, gestational diabet...
# 1                                               None
# 2                               gestational diabetes
# 3                                  diabetes mellitus
# 4  hiv infection, hiv infection, diabetes mellitu...
#
#    seriousness_congenital_anomaly target_medicinal_product  \
# 0                             1.0                  insulin
# 1                             NaN                  insulin
# 2                             1.0                  insulin
# 3                             NaN         insulin glargine
# 4                             1.0                  insulin
#
#                              other_medicinal_product  \
# 0  metoprolol (unknown), bisoprolol, folio, dopeg...
# 1  hydralazine, methyldopa, telmisartan, amlodipi...
# 2                       effexor, zyprexa, levothyrox
# 3                                  solostar, humalog
# 4  combivir, kaletra, metformin, nexium, prenatal...
#
#                             pregnancy_reaction_event  \
# 0                   foetal exposure during pregnancy
# 1  foetal death, foetal heart rate deceleration a...
# 2                   foetal exposure during pregnancy
# 3       ectopic pregnancy, exposure during pregnancy
# 4                   foetal exposure during pregnancy
#
#                                 other_reaction_event
# 0       congenital hydronephrosis, ureteric stenosis
# 1                                     premature baby
# 2                  multiple congenital abnormalities
# 3                            no therapeutic response
# 4  ventricular septal defect, atrial septal defec...
#
# --------------------------------------------------
#
# Inspecting table: table4
#                     condition number_one_drug_used fda_pregnancy_risk_category
# 0      pre_pregnancy_diabetes              insulin                           a
# 1        gestational_diabetes              insulin                           a
# 2  pre_pregnancy_hypertension            labetalol                           c
# 3    gestational_hypertension            labetalol                           c
# 4                   eclampsia    magnesium sulfate                           a
#
# --------------------------------------------------

# %%
# Query to get the number of rows in table1
count_query = "SELECT COUNT(*) FROM table1"
row_count = pd.read_sql_query(count_query, conn)
print(f"Number of rows in table1: {row_count.iloc[0, 0]}")
# Out:
# Number of rows in table1: 43

# %% [markdown]
# ## Joining Table 1 and Table 4
# join table 1 by satisfying yes to certain conditions found in table 4.

# %% [markdown]
# ### Inspect Table1

# %%
# Get the columns from table1
columns = ['notes', 'census_region', 'census_region_code', 'chlamydia', 'cause_of_death', 'deaths', 
           'births', 'death_rate', 'eclampsia', 'gestational_diabetes', 'gestational_hypertension', 
           'gonorrhea', 'hepatitis_b', 'hepatitis_c', 'pre_pregnancy_diabetes', 'pre_pregnancy_hypertension', 
           'previous_preterm_birth', 'syphilis', 'tobacco_use']

# Loop through each column and print unique values
for column in columns:
    query = f"SELECT DISTINCT {column} FROM table1"
    unique_values = pd.read_sql_query(query, conn)  # Execute the query and get the result as a DataFrame
    print(f"Unique values in column '{column}':")
    print(unique_values[column].to_list())  # Print the unique values for the column
    print("\n")
# Out:
# Unique values in column 'notes':
# ['total']
#
#
# Unique values in column 'census_region':
# ['census region 2: midwest', 'census region 3: south', 'census region 4: west', 'census region 1: northeast']
#
#
# Unique values in column 'census_region_code':
# ['cens-r2', 'cens-r3', 'cens-r4', 'cens-r1']
#
#
# Unique values in column 'chlamydia':
# ['yes', 'unknown']
#
#
# Unique values in column 'cause_of_death':
# ['unknown']
#
#
# Unique values in column 'deaths':
# [143.0, 256.0, 71.0, 18.0, 46.0, 25.0, 129.0, 273.0, 462.0, 253.0, 228.0, 488.0, 924.0, 356.0, 16.0, 47.0, 74.0, 12.0, 27.0, 52.0, 21.0, 60.0, 103.0, 223.0, 86.0, 132.0, 267.0, 482.0, 162.0, 501.0, 807.0, 263.0, 14.0, 20.0, 64.0, 33.0, 220.0, 540.0, 696.0, 171.0]
#
#
# Unique values in column 'births':
# [14093.0, 30595.0, 10300.0, 2029.0, 3280.0, 3151.0, 50851.0, 64914.0, 105341.0, 75345.0, 50171.0, 81230.0, 141878.0, 75141.0, 1025.0, 2740.0, 5689.0, 1494.0, 1764.0, 3100.0, 4031.0, 6309.0, 2063.0, 6580.0, 9438.0, 17906.0, 8879.0, 18064.0, 24997.0, 46520.0, 17191.0, 24231.0, 37587.0, 55358.0, 25205.0, 1053.0, 1928.0, 4898.0, 2353.0, 18684.0, 45140.0, 53564.0, 16753.0]
#
#
# Unique values in column 'death_rate':
# ['10.15', '8.37', '6.89', '8.87 (unreliable)', '14.02', '7.93', '2.54', '4.21', '4.39', '3.36', '4.54', '6.01', '6.51', '4.74', '15.61 (unreliable)', '17.15', '13.01', '8.03 (unreliable)', '10.20 (unreliable)', '8.71', '12.90', '11.25', '10.18', '9.12', '10.91', '12.45', '9.69', '7.31', '10.68', '10.36', '9.42', '10.56', '13.33', '14.58', '10.43', '13.30 (unreliable)', '10.37', '13.07', '11.77', '11.96', '12.99', '10.21']
#
#
# Unique values in column 'eclampsia':
# ['unknown', 'yes']
#
#
# Unique values in column 'gestational_diabetes':
# ['unknown', 'yes']
#
#
# Unique values in column 'gestational_hypertension':
# ['unknown', 'yes']
#
#
# Unique values in column 'gonorrhea':
# ['unknown', 'yes']
#
#
# Unique values in column 'hepatitis_b':
# ['unknown', 'yes']
#
#
# Unique values in column 'hepatitis_c':
# ['unknown', 'yes']
#
#
# Unique values in column 'pre_pregnancy_diabetes':
# ['unknown', 'yes']
#
#
# Unique values in column 'pre_pregnancy_hypertension':
# ['unknown', 'yes']
#
#
# Unique values in column 'previous_preterm_birth':
# ['unknown', 'yes']
#
#
# Unique values in column 'syphilis':
# ['unknown', 'yes']
#
#
# Unique values in column 'tobacco_use':
# ['unknown', 'yes']

# %% [markdown]
# ### Check Table 4

# %%
# SQL query to fetch unique values from the 'condition' column of table4
query_table4_unique = "SELECT DISTINCT condition FROM table4;"

# Execute the query and load the results into a pandas DataFrame
df_table4_unique = pd.read_sql_query(query_table4_unique, conn)

# Display the unique rows in the 'condition' column of table4
df_table4_unique
# Out:
#                      condition
# 0       pre_pregnancy_diabetes
# 1         gestational_diabetes
# 2   pre_pregnancy_hypertension
# 3     gestational_hypertension
# 4                    eclampsia
# 5       previous_preterm_birth
# 6                    gonorrhea
# 7                     syphilis
# 8                    chlamydia
# 9                  hepatitis_b
# 10                 hepatitis_c
# 11                    nicotine

# %%
# Define the SQL query to count the 'yes' values in each column of interest
query = """
SELECT
    SUM(CASE WHEN LOWER(chlamydia) = 'yes' THEN 1 ELSE 0 END) AS chlamydia_yes,
    SUM(CASE WHEN LOWER(eclampsia) = 'yes' THEN 1 ELSE 0 END) AS eclampsia_yes,
    SUM(CASE WHEN LOWER(gestational_diabetes) = 'yes' THEN 1 ELSE 0 END) AS gestational_diabetes_yes,
    SUM(CASE WHEN LOWER(gestational_hypertension) = 'yes' THEN 1 ELSE 0 END) AS gestational_hypertension_yes,
    SUM(CASE WHEN LOWER(gonorrhea) = 'yes' THEN 1 ELSE 0 END) AS gonorrhea_yes,
    SUM(CASE WHEN LOWER(hepatitis_b) = 'yes' THEN 1 ELSE 0 END) AS hepatitis_b_yes,
    SUM(CASE WHEN LOWER(hepatitis_c) = 'yes' THEN 1 ELSE 0 END) AS hepatitis_c_yes,
    SUM(CASE WHEN LOWER(pre_pregnancy_diabetes) = 'yes' THEN 1 ELSE 0 END) AS pre_pregnancy_diabetes_yes,
    SUM(CASE WHEN LOWER(pre_pregnancy_hypertension) = 'yes' THEN 1 ELSE 0 END) AS pre_pregnancy_hypertension_yes,
    SUM(CASE WHEN LOWER(previous_preterm_birth) = 'yes' THEN 1 ELSE 0 END) AS previous_preterm_birth_yes,
    SUM(CASE WHEN LOWER(syphilis) = 'yes' THEN 1 ELSE 0 END) AS syphilis_yes,
    SUM(CASE WHEN LOWER(tobacco_use) = 'yes' THEN 1 ELSE 0 END) AS tobacco_use_yes
FROM table1;
"""

# Execute the SQL query and load the result into a pandas DataFrame
yes_counts = pd.read_sql_query(query, conn)

# Display the result
print("Total 'yes' values in each column:")
print(yes_counts)
# Out:
# Total 'yes' values in each column:
#    chlamydia_yes  eclampsia_yes  gestational_diabetes_yes  \
# 0              3              3                         4
#
#    gestational_hypertension_yes  gonorrhea_yes  hepatitis_b_yes  \
# 0                             4              4                1
#
#    hepatitis_c_yes  pre_pregnancy_diabetes_yes  \
# 0                4                           4
#
#    pre_pregnancy_hypertension_yes  previous_preterm_birth_yes  syphilis_yes  \
# 0                               4                           4             4
#
#    tobacco_use_yes
# 0                4

# %%
# Query to get column names from table1
query_table1 = "PRAGMA table_info(table1);"
columns_table1 = pd.read_sql_query(query_table1, conn)

# Query to get column names from table4
query_table4 = "PRAGMA table_info(table4);"
columns_table4 = pd.read_sql_query(query_table4, conn)

# Display the column names
print("Columns in table1:")
print(columns_table1['name'].tolist())  # 'name' contains column names in the result

print("\nColumns in table4:")
print(columns_table4['name'].tolist())  # 'name' contains column names in the result
# Out:
# Columns in table1:
# ['notes', 'census_region', 'census_region_code', 'chlamydia', 'cause_of_death', 'deaths', 'births', 'death_rate', 'eclampsia', 'gestational_diabetes', 'gestational_hypertension', 'gonorrhea', 'hepatitis_b', 'hepatitis_c', 'pre_pregnancy_diabetes', 'pre_pregnancy_hypertension', 'previous_preterm_birth', 'syphilis', 'tobacco_use']
#
# Columns in table4:
# ['condition', 'number_one_drug_used', 'fda_pregnancy_risk_category']

# %%
# Check the data types of columns in table1
query_table1 = "PRAGMA table_info(table1);"
table1_info = pd.read_sql_query(query_table1, conn)
print("Columns and data types for table1:")
print(table1_info)

# Check the data types of columns in table4
query_table4 = "PRAGMA table_info(table4);"
table4_info = pd.read_sql_query(query_table4, conn)
print("\nColumns and data types for table4:")
print(table4_info)
# Out:
# Columns and data types for table1:
#     cid                        name  type  notnull dflt_value  pk
# 0     0                       notes  TEXT        0       None   0
# 1     1               census_region  TEXT        0       None   0
# 2     2          census_region_code  TEXT        0       None   0
# 3     3                   chlamydia  TEXT        0       None   0
# 4     4              cause_of_death  TEXT        0       None   0
# 5     5                      deaths  REAL        0       None   0
# 6     6                      births  REAL        0       None   0
# 7     7                  death_rate  TEXT        0       None   0
# 8     8                   eclampsia  TEXT        0       None   0
# 9     9        gestational_diabetes  TEXT        0       None   0
# 10   10    gestational_hypertension  TEXT        0       None   0
# 11   11                   gonorrhea  TEXT        0       None   0
# 12   12                 hepatitis_b  TEXT        0       None   0
# 13   13                 hepatitis_c  TEXT        0       None   0
# 14   14      pre_pregnancy_diabetes  TEXT        0       None   0
# 15   15  pre_pregnancy_hypertension  TEXT        0       None   0
# 16   16      previous_preterm_birth  TEXT        0       None   0
# 17   17                    syphilis  TEXT        0       None   0
# 18   18                 tobacco_use  TEXT        0       None   0
#
# Columns and data types for table4:
#    cid                         name  type  notnull dflt_value  pk
# 0    0                    condition  TEXT        0       None   0
# 1    1         number_one_drug_used  TEXT        0       None   0
# 2    2  fda_pregnancy_risk_category  TEXT        0       None   0

# %%
# Create result_table with the same data types as table1 and table4
create_table_query = """
CREATE TABLE IF NOT EXISTS result_table (
    notes TEXT,
    census_region TEXT,
    census_region_code TEXT,
    chlamydia TEXT,
    cause_of_death TEXT,
    deaths REAL,
    births REAL,
    death_rate TEXT,
    eclampsia TEXT,
    gestational_diabetes TEXT,
    gestational_hypertension TEXT,
    gonorrhea TEXT,
    hepatitis_b TEXT,
    hepatitis_c TEXT,
    pre_pregnancy_diabetes TEXT,
    pre_pregnancy_hypertension TEXT,
    previous_preterm_birth TEXT,
    syphilis TEXT,
    tobacco_use TEXT,
    condition TEXT,
    number_one_drug_used TEXT,
    fda_pregnancy_risk_category TEXT
);
"""

# Execute the query to create the table
conn.execute(create_table_query)

# %%
# SQL query to perform the join and insert into result_table
query = """
INSERT INTO result_table
SELECT t1.notes, t1.census_region, t1.census_region_code, t1.chlamydia, t1.cause_of_death,
       t1.deaths, t1.births, t1.death_rate, t1.eclampsia, t1.gestational_diabetes, 
       t1.gestational_hypertension, t1.gonorrhea, t1.hepatitis_b, t1.hepatitis_c,
       t1.pre_pregnancy_diabetes, t1.pre_pregnancy_hypertension, t1.previous_preterm_birth,
       t1.syphilis, t1.tobacco_use, t4.condition, t4.number_one_drug_used, t4.fda_pregnancy_risk_category
FROM table1 AS t1
JOIN table4 AS t4
    ON (LOWER(t1.chlamydia) = 'yes' AND LOWER(t4.condition) = 'chlamydia')
    OR (LOWER(t1.eclampsia) = 'yes' AND LOWER(t4.condition) = 'eclampsia')
    OR (LOWER(t1.gestational_diabetes) = 'yes' AND LOWER(t4.condition) = 'gestational_diabetes')
    OR (LOWER(t1.gestational_hypertension) = 'yes' AND LOWER(t4.condition) = 'gestational_hypertension')
    OR (LOWER(t1.gonorrhea) = 'yes' AND LOWER(t4.condition) = 'gonorrhea')
    OR (LOWER(t1.hepatitis_b) = 'yes' AND LOWER(t4.condition) = 'hepatitis_b')
    OR (LOWER(t1.hepatitis_c) = 'yes' AND LOWER(t4.condition) = 'hepatitis_c')
    OR (LOWER(t1.pre_pregnancy_diabetes) = 'yes' AND LOWER(t4.condition) = 'pre_pregnancy_diabetes')
    OR (LOWER(t1.pre_pregnancy_hypertension) = 'yes' AND LOWER(t4.condition) = 'pre_pregnancy_hypertension')
    OR (LOWER(t1.previous_preterm_birth) = 'yes' AND LOWER(t4.condition) = 'previous_preterm_birth')
    OR (LOWER(t1.syphilis) = 'yes' AND LOWER(t4.condition) = 'syphilis')
    OR (LOWER(t1.tobacco_use) = 'yes' AND LOWER(t4.condition) = 'nicotine')
"""

# Execute the SQL query to perform the join and insert the result into result_table
conn.execute(query)

# Commit the changes to the database
conn.commit()

# verify the data
df_check = pd.read_sql_query("SELECT * FROM result_table", conn)

# Display the first few rows to verify the insert
print(df_check.head())

# Check the number of rows and columns in the result table
print(f"Total rows in result_table: {df_check.shape[0]}")
print(f"Total columns in result_table: {df_check.shape[1]}")
# Out:
#    notes             census_region census_region_code chlamydia  \
# 0  total  census region 2: midwest            cens-r2       yes
# 1  total    census region 3: south            cens-r3       yes
# 2  total     census region 4: west            cens-r4       yes
# 3  total  census region 2: midwest            cens-r2   unknown
# 4  total    census region 3: south            cens-r3   unknown
#
#   cause_of_death  deaths   births         death_rate eclampsia  \
# 0        unknown   143.0  14093.0              10.15   unknown
# 1        unknown   256.0  30595.0               8.37   unknown
# 2        unknown    71.0  10300.0               6.89   unknown
# 3        unknown    18.0   2029.0  8.87 (unreliable)       yes
# 4        unknown    46.0   3280.0              14.02       yes
#
#   gestational_diabetes  ... hepatitis_b hepatitis_c pre_pregnancy_diabetes  \
# 0              unknown  ...     unknown     unknown                unknown
# 1              unknown  ...     unknown     unknown                unknown
# 2              unknown  ...     unknown     unknown                unknown
# 3              unknown  ...     unknown     unknown                unknown
# 4              unknown  ...     unknown     unknown                unknown
#
#   pre_pregnancy_hypertension previous_preterm_birth syphilis tobacco_use  \
# 0                    unknown                unknown  unknown     unknown
# 1                    unknown                unknown  unknown     unknown
# 2                    unknown                unknown  unknown     unknown
# 3                    unknown                unknown  unknown     unknown
# 4                    unknown                unknown  unknown     unknown
#
#    condition number_one_drug_used fda_pregnancy_risk_category
# 0  chlamydia         azithromycin                           b
# 1  chlamydia         azithromycin                           b
# 2  chlamydia         azithromycin                           b
# 3  eclampsia    magnesium sulfate                           a
# 4  eclampsia    magnesium sulfate                           a
#
# [5 rows x 22 columns]
# Total rows in result_table: 43
# Total columns in result_table: 22

# %% [markdown]
# ### Joining Table 2
# join table 2 based on pregnancy category and fda_pregnancy risk

# %%
# inspect table 2 pregnancy category unique values
# Connect to (or create) an SQLite database
conn = sqlite3.connect("pregnancy_database.db")
cursor = conn.cursor()

# Query to check the unique values of the 'pregnancy_category' column in table2
query = "SELECT DISTINCT pregnancy_category FROM table2;"
unique_pregnancy_categories = pd.read_sql_query(query, conn)

# Display the unique values
print(unique_pregnancy_categories)
# Out:
#   pregnancy_category
# 0                  a
# 1                  b
# 2                  c
# 3                  d
# 4                  x
# 5                  n

# %%
# inpsect column names 
# Query to check the column names of table2
query = "PRAGMA table_info(table2);"
column_info_table2 = pd.read_sql_query(query, conn)

# Display the column names and data types
column_info_table2[['name', 'type']]
# Out:
#                    name  type
# 0    pregnancy_category  TEXT
# 1                  risk  TEXT
# 2  detailed_description  TEXT

# %%
# List all tables in the database
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
print(pd.read_sql_query(tables_query, conn))

# Check schema for return_table
schema_query = "PRAGMA table_info(return_table);"
print(pd.read_sql_query(schema_query, conn))
# Out:
#            name
# 0        table1
# 1        table2
# 2        table3
# 3        table4
# 4  result_table
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
# SQL query to add one column at a time
alter_table_query_1 = "ALTER TABLE result_table ADD COLUMN risk TEXT;"
alter_table_query_2 = "ALTER TABLE result_table ADD COLUMN detailed_description TEXT;"

# Execute the queries one by one
conn.execute(alter_table_query_1)
conn.execute(alter_table_query_2)

# Commit changes
conn.commit()

print("Columns 'risk' and 'detailed_description' have been added to 'result_table'.")
# Out:
# Columns 'risk' and 'detailed_description' have been added to 'result_table'.

# %%
# SQL query to update the result_table with risk and detailed_description from table2
update_query = """
UPDATE result_table
SET risk = (SELECT t2.risk 
            FROM table2 AS t2 
            WHERE t2.pregnancy_category = result_table.fda_pregnancy_risk_category),
    detailed_description = (SELECT t2.detailed_description 
                            FROM table2 AS t2 
                            WHERE t2.pregnancy_category = result_table.fda_pregnancy_risk_category);
"""

# Execute the update query
conn.execute(update_query)

# Commit the changes to the database
conn.commit()

# Verify the update by fetching a few rows from the result_table
df_check_updated = pd.read_sql_query("SELECT * FROM result_table;", conn)
print(df_check_updated)
# Out:
#     notes               census_region census_region_code chlamydia  \
# 0   total    census region 2: midwest            cens-r2       yes
# 1   total      census region 3: south            cens-r3       yes
# 2   total       census region 4: west            cens-r4       yes
# 3   total    census region 2: midwest            cens-r2   unknown
# 4   total      census region 3: south            cens-r3   unknown
# 5   total       census region 4: west            cens-r4   unknown
# 6   total  census region 1: northeast            cens-r1   unknown
# 7   total    census region 2: midwest            cens-r2   unknown
# 8   total      census region 3: south            cens-r3   unknown
# 9   total       census region 4: west            cens-r4   unknown
# 10  total  census region 1: northeast            cens-r1   unknown
# 11  total    census region 2: midwest            cens-r2   unknown
# 12  total      census region 3: south            cens-r3   unknown
# 13  total       census region 4: west            cens-r4   unknown
# 14  total  census region 1: northeast            cens-r1   unknown
# 15  total    census region 2: midwest            cens-r2   unknown
# 16  total      census region 3: south            cens-r3   unknown
# 17  total       census region 4: west            cens-r4   unknown
# 18  total      census region 3: south            cens-r3   unknown
# 19  total  census region 1: northeast            cens-r1   unknown
# 20  total    census region 2: midwest            cens-r2   unknown
# 21  total      census region 3: south            cens-r3   unknown
# 22  total       census region 4: west            cens-r4   unknown
# 23  total  census region 1: northeast            cens-r1   unknown
# 24  total    census region 2: midwest            cens-r2   unknown
# 25  total      census region 3: south            cens-r3   unknown
# 26  total       census region 4: west            cens-r4   unknown
# 27  total  census region 1: northeast            cens-r1   unknown
# 28  total    census region 2: midwest            cens-r2   unknown
# 29  total      census region 3: south            cens-r3   unknown
# 30  total       census region 4: west            cens-r4   unknown
# 31  total  census region 1: northeast            cens-r1   unknown
# 32  total    census region 2: midwest            cens-r2   unknown
# 33  total      census region 3: south            cens-r3   unknown
# 34  total       census region 4: west            cens-r4   unknown
# 35  total  census region 1: northeast            cens-r1   unknown
# 36  total    census region 2: midwest            cens-r2   unknown
# 37  total      census region 3: south            cens-r3   unknown
# 38  total       census region 4: west            cens-r4   unknown
# 39  total  census region 1: northeast            cens-r1   unknown
# 40  total    census region 2: midwest            cens-r2   unknown
# 41  total      census region 3: south            cens-r3   unknown
# 42  total       census region 4: west            cens-r4   unknown
#
#    cause_of_death  deaths    births          death_rate eclampsia  \
# 0         unknown   143.0   14093.0               10.15   unknown
# 1         unknown   256.0   30595.0                8.37   unknown
# 2         unknown    71.0   10300.0                6.89   unknown
# 3         unknown    18.0    2029.0   8.87 (unreliable)       yes
# 4         unknown    46.0    3280.0               14.02       yes
# 5         unknown    25.0    3151.0                7.93       yes
# 6         unknown   129.0   50851.0                2.54   unknown
# 7         unknown   273.0   64914.0                4.21   unknown
# 8         unknown   462.0  105341.0                4.39   unknown
# 9         unknown   253.0   75345.0                3.36   unknown
# 10        unknown   228.0   50171.0                4.54   unknown
# 11        unknown   488.0   81230.0                6.01   unknown
# 12        unknown   924.0  141878.0                6.51   unknown
# 13        unknown   356.0   75141.0                4.74   unknown
# 14        unknown    16.0    1025.0  15.61 (unreliable)   unknown
# 15        unknown    47.0    2740.0               17.15   unknown
# 16        unknown    74.0    5689.0               13.01   unknown
# 17        unknown    12.0    1494.0   8.03 (unreliable)   unknown
# 18        unknown    18.0    1764.0  10.20 (unreliable)   unknown
# 19        unknown    27.0    3100.0                8.71   unknown
# 20        unknown    52.0    4031.0               12.90   unknown
# 21        unknown    71.0    6309.0               11.25   unknown
# 22        unknown    21.0    2063.0               10.18   unknown
# 23        unknown    60.0    6580.0                9.12   unknown
# 24        unknown   103.0    9438.0               10.91   unknown
# 25        unknown   223.0   17906.0               12.45   unknown
# 26        unknown    86.0    8879.0                9.69   unknown
# 27        unknown   132.0   18064.0                7.31   unknown
# 28        unknown   267.0   24997.0               10.68   unknown
# 29        unknown   482.0   46520.0               10.36   unknown
# 30        unknown   162.0   17191.0                9.42   unknown
# 31        unknown   256.0   24231.0               10.56   unknown
# 32        unknown   501.0   37587.0               13.33   unknown
# 33        unknown   807.0   55358.0               14.58   unknown
# 34        unknown   263.0   25205.0               10.43   unknown
# 35        unknown    14.0    1053.0  13.30 (unreliable)   unknown
# 36        unknown    20.0    1928.0               10.37   unknown
# 37        unknown    64.0    4898.0               13.07   unknown
# 38        unknown    33.0    2353.0               14.02   unknown
# 39        unknown   220.0   18684.0               11.77   unknown
# 40        unknown   540.0   45140.0               11.96   unknown
# 41        unknown   696.0   53564.0               12.99   unknown
# 42        unknown   171.0   16753.0               10.21   unknown
#
#    gestational_diabetes gestational_hypertension gonorrhea hepatitis_b  \
# 0               unknown                  unknown   unknown     unknown
# 1               unknown                  unknown   unknown     unknown
# 2               unknown                  unknown   unknown     unknown
# 3               unknown                  unknown   unknown     unknown
# 4               unknown                  unknown   unknown     unknown
# 5               unknown                  unknown   unknown     unknown
# 6                   yes                  unknown   unknown     unknown
# 7                   yes                  unknown   unknown     unknown
# 8                   yes                  unknown   unknown     unknown
# 9                   yes                  unknown   unknown     unknown
# 10              unknown                      yes   unknown     unknown
# 11              unknown                      yes   unknown     unknown
# 12              unknown                      yes   unknown     unknown
# 13              unknown                      yes   unknown     unknown
# 14              unknown                  unknown       yes     unknown
# 15              unknown                  unknown       yes     unknown
# 16              unknown                  unknown       yes     unknown
# 17              unknown                  unknown       yes     unknown
# 18              unknown                  unknown   unknown         yes
# 19              unknown                  unknown   unknown     unknown
# 20              unknown                  unknown   unknown     unknown
# 21              unknown                  unknown   unknown     unknown
# 22              unknown                  unknown   unknown     unknown
# 23              unknown                  unknown   unknown     unknown
# 24              unknown                  unknown   unknown     unknown
# 25              unknown                  unknown   unknown     unknown
# 26              unknown                  unknown   unknown     unknown
# 27              unknown                  unknown   unknown     unknown
# 28              unknown                  unknown   unknown     unknown
# 29              unknown                  unknown   unknown     unknown
# 30              unknown                  unknown   unknown     unknown
# 31              unknown                  unknown   unknown     unknown
# 32              unknown                  unknown   unknown     unknown
# 33              unknown                  unknown   unknown     unknown
# 34              unknown                  unknown   unknown     unknown
# 35              unknown                  unknown   unknown     unknown
# 36              unknown                  unknown   unknown     unknown
# 37              unknown                  unknown   unknown     unknown
# 38              unknown                  unknown   unknown     unknown
# 39              unknown                  unknown   unknown     unknown
# 40              unknown                  unknown   unknown     unknown
# 41              unknown                  unknown   unknown     unknown
# 42              unknown                  unknown   unknown     unknown
#
#    hepatitis_c pre_pregnancy_diabetes pre_pregnancy_hypertension  \
# 0      unknown                unknown                    unknown
# 1      unknown                unknown                    unknown
# 2      unknown                unknown                    unknown
# 3      unknown                unknown                    unknown
# 4      unknown                unknown                    unknown
# 5      unknown                unknown                    unknown
# 6      unknown                unknown                    unknown
# 7      unknown                unknown                    unknown
# 8      unknown                unknown                    unknown
# 9      unknown                unknown                    unknown
# 10     unknown                unknown                    unknown
# 11     unknown                unknown                    unknown
# 12     unknown                unknown                    unknown
# 13     unknown                unknown                    unknown
# 14     unknown                unknown                    unknown
# 15     unknown                unknown                    unknown
# 16     unknown                unknown                    unknown
# 17     unknown                unknown                    unknown
# 18     unknown                unknown                    unknown
# 19         yes                unknown                    unknown
# 20         yes                unknown                    unknown
# 21         yes                unknown                    unknown
# 22         yes                unknown                    unknown
# 23     unknown                    yes                    unknown
# 24     unknown                    yes                    unknown
# 25     unknown                    yes                    unknown
# 26     unknown                    yes                    unknown
# 27     unknown                unknown                        yes
# 28     unknown                unknown                        yes
# 29     unknown                unknown                        yes
# 30     unknown                unknown                        yes
# 31     unknown                unknown                    unknown
# 32     unknown                unknown                    unknown
# 33     unknown                unknown                    unknown
# 34     unknown                unknown                    unknown
# 35     unknown                unknown                    unknown
# 36     unknown                unknown                    unknown
# 37     unknown                unknown                    unknown
# 38     unknown                unknown                    unknown
# 39     unknown                unknown                    unknown
# 40     unknown                unknown                    unknown
# 41     unknown                unknown                    unknown
# 42     unknown                unknown                    unknown
#
#    previous_preterm_birth syphilis tobacco_use                   condition  \
# 0                 unknown  unknown     unknown                   chlamydia
# 1                 unknown  unknown     unknown                   chlamydia
# 2                 unknown  unknown     unknown                   chlamydia
# 3                 unknown  unknown     unknown                   eclampsia
# 4                 unknown  unknown     unknown                   eclampsia
# 5                 unknown  unknown     unknown                   eclampsia
# 6                 unknown  unknown     unknown        gestational_diabetes
# 7                 unknown  unknown     unknown        gestational_diabetes
# 8                 unknown  unknown     unknown        gestational_diabetes
# 9                 unknown  unknown     unknown        gestational_diabetes
# 10                unknown  unknown     unknown    gestational_hypertension
# 11                unknown  unknown     unknown    gestational_hypertension
# 12                unknown  unknown     unknown    gestational_hypertension
# 13                unknown  unknown     unknown    gestational_hypertension
# 14                unknown  unknown     unknown                   gonorrhea
# 15                unknown  unknown     unknown                   gonorrhea
# 16                unknown  unknown     unknown                   gonorrhea
# 17                unknown  unknown     unknown                   gonorrhea
# 18                unknown  unknown     unknown                 hepatitis_b
# 19                unknown  unknown     unknown                 hepatitis_c
# 20                unknown  unknown     unknown                 hepatitis_c
# 21                unknown  unknown     unknown                 hepatitis_c
# 22                unknown  unknown     unknown                 hepatitis_c
# 23                unknown  unknown     unknown      pre_pregnancy_diabetes
# 24                unknown  unknown     unknown      pre_pregnancy_diabetes
# 25                unknown  unknown     unknown      pre_pregnancy_diabetes
# 26                unknown  unknown     unknown      pre_pregnancy_diabetes
# 27                unknown  unknown     unknown  pre_pregnancy_hypertension
# 28                unknown  unknown     unknown  pre_pregnancy_hypertension
# 29                unknown  unknown     unknown  pre_pregnancy_hypertension
# 30                unknown  unknown     unknown  pre_pregnancy_hypertension
# 31                    yes  unknown     unknown      previous_preterm_birth
# 32                    yes  unknown     unknown      previous_preterm_birth
# 33                    yes  unknown     unknown      previous_preterm_birth
# 34                    yes  unknown     unknown      previous_preterm_birth
# 35                unknown      yes     unknown                    syphilis
# 36                unknown      yes     unknown                    syphilis
# 37                unknown      yes     unknown                    syphilis
# 38                unknown      yes     unknown                    syphilis
# 39                unknown  unknown         yes                    nicotine
# 40                unknown  unknown         yes                    nicotine
# 41                unknown  unknown         yes                    nicotine
# 42                unknown  unknown         yes                    nicotine
#
#                 number_one_drug_used fda_pregnancy_risk_category  \
# 0                       azithromycin                           b
# 1                       azithromycin                           b
# 2                       azithromycin                           b
# 3                  magnesium sulfate                           a
# 4                  magnesium sulfate                           a
# 5                  magnesium sulfate                           a
# 6                            insulin                           a
# 7                            insulin                           a
# 8                            insulin                           a
# 9                            insulin                           a
# 10                         labetalol                           c
# 11                         labetalol                           c
# 12                         labetalol                           c
# 13                         labetalol                           c
# 14                       ceftriaxone                           b
# 15                       ceftriaxone                           b
# 16                       ceftriaxone                           b
# 17                       ceftriaxone                           b
# 18                        lamivudine                           b
# 19  avoid treatment during pregnancy                           n
# 20  avoid treatment during pregnancy                           n
# 21  avoid treatment during pregnancy                           n
# 22  avoid treatment during pregnancy                           n
# 23                           insulin                           a
# 24                           insulin                           a
# 25                           insulin                           a
# 26                           insulin                           a
# 27                         labetalol                           c
# 28                         labetalol                           c
# 29                         labetalol                           c
# 30                         labetalol                           c
# 31                     progesterone                            b
# 32                     progesterone                            b
# 33                     progesterone                            b
# 34                     progesterone                            b
# 35                      penicillin g                           b
# 36                      penicillin g                           b
# 37                      penicillin g                           b
# 38                      penicillin g                           b
# 39                          nicotine                           d
# 40                          nicotine                           d
# 41                          nicotine                           d
# 42                          nicotine                           d
#
#                                                                             risk  \
# 0                                                       no risk in other studies
# 1                                                       no risk in other studies
# 2                                                       no risk in other studies
# 3                                            no risk in controlled human studies
# 4                                            no risk in controlled human studies
# 5                                            no risk in controlled human studies
# 6                                            no risk in controlled human studies
# 7                                            no risk in controlled human studies
# 8                                            no risk in controlled human studies
# 9                                            no risk in controlled human studies
# 10                                                            risk not ruled out
# 11                                                            risk not ruled out
# 12                                                            risk not ruled out
# 13                                                            risk not ruled out
# 14                                                      no risk in other studies
# 15                                                      no risk in other studies
# 16                                                      no risk in other studies
# 17                                                      no risk in other studies
# 18                                                      no risk in other studies
# 19  the fda has not yet classified the drug into a specified pregnancy category.
# 20  the fda has not yet classified the drug into a specified pregnancy category.
# 21  the fda has not yet classified the drug into a specified pregnancy category.
# 22  the fda has not yet classified the drug into a specified pregnancy category.
# 23                                           no risk in controlled human studies
# 24                                           no risk in controlled human studies
# 25                                           no risk in controlled human studies
# 26                                           no risk in controlled human studies
# 27                                                            risk not ruled out
# 28                                                            risk not ruled out
# 29                                                            risk not ruled out
# 30                                                            risk not ruled out
# 31                                                      no risk in other studies
# 32                                                      no risk in other studies
# 33                                                      no risk in other studies
# 34                                                      no risk in other studies
# 35                                                      no risk in other studies
# 36                                                      no risk in other studies
# 37                                                      no risk in other studies
# 38                                                      no risk in other studies
# 39                                                     positive evidence of risk
# 40                                                     positive evidence of risk
# 41                                                     positive evidence of risk
# 42                                                     positive evidence of risk
#
#                                                                                                                                                                                                                                                                                                               detailed_description
# 0    animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 1    animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 2    animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 3                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 4                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 5                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 6                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 7                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 8                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 9                                                                                                                                            adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 10                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 11                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 12                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 13                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 14   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 15   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 16   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 17   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 18   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 19                                                                                                                                                                                                                                                                                                                            None
# 20                                                                                                                                                                                                                                                                                                                            None
# 21                                                                                                                                                                                                                                                                                                                            None
# 22                                                                                                                                                                                                                                                                                                                            None
# 23                                                                                                                                           adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 24                                                                                                                                           adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 25                                                                                                                                           adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 26                                                                                                                                           adequate and well-controlled human studies have failed to demonstrate a risk to the fetus in the first trimester of pregnancy (and there is no evidence of risk in later trimesters).
# 27                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 28                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 29                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 30                                                                                            animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 31   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 32   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 33   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 34   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 35   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 36   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 37   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 38   animal reproduction studies have failed to demonstrate a risk to the fetus and there are no adequate and well-controlled studies in pregnant women, or animal studies have shown adverse effects, but adequate and well-controlled studies in pregnant women have failed to demonstrate a risk to the fetus in any trimester.
# 39                                                                                  there is positive evidence of human fetal risk based on adverse reaction data from investigational or marketing experience or studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 40                                                                                  there is positive evidence of human fetal risk based on adverse reaction data from investigational or marketing experience or studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 41                                                                                  there is positive evidence of human fetal risk based on adverse reaction data from investigational or marketing experience or studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.
# 42                                                                                  there is positive evidence of human fetal risk based on adverse reaction data from investigational or marketing experience or studies in humans, but potential benefits may warrant use of the drug in pregnant women despite potential risks.

# %% [markdown]
# # Visualizations

# %%
try:
    # Query to get the count of each unique target_medicinal_product
    query = """
    SELECT target_medicinal_product, COUNT(*) as product_count
    FROM table3
    GROUP BY target_medicinal_product;
    """

    # Execute the query and fetch results into a DataFrame
    product_counts_df = pd.read_sql_query(query, conn)

    # Display the result
    print("Count of each unique target_medicinal_product:")
    print(product_counts_df)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Count of each unique target_medicinal_product:
#                              target_medicinal_product  product_count
# 0                                        azithromycin              3
# 1   azithromycin, azithromycin, lamivudine, lamivu...              1
# 2                                         ceftriaxone              5
# 3                 ceftriaxone injection, azithromycin              1
# 4                                             insulin              4
# 5                                    insulin glargine              1
# 6                                           labetalol              4
# 7                                labetalol, labetalol              1
# 8                                          lamivudine              1
# 9                           lamivudine and zidovudine              1
# 10                                     lamivudine-hiv              2
# 11                                  magnesium sulfate              1
# 12                                 magnesium sulfate.              4
# 13                                           nicotine              4
# 14                                    nicotine (none)              1
# 15                                       penicillin g              2
# 16                   penicillin g potassium injection              2
# 17  penicillin g potassium injection, penicillin g...              1
# 18                                       progesterone              3
# 19                            progesterone (solution)              1
# 20                                      progesterone.              1

# %%
# Query to get unique values from number_one_drug_used
query = "SELECT DISTINCT number_one_drug_used FROM result_table;"

# Execute the query and load the result into a DataFrame
unique_drugs_df = pd.read_sql_query(query, conn)

# Print the unique values
print(unique_drugs_df['number_one_drug_used'].tolist())
# Out:
# ['azithromycin', 'magnesium sulfate', 'insulin', 'labetalol', 'ceftriaxone', 'lamivudine', 'avoid treatment during pregnancy', 'progesterone ', 'penicillin g', 'nicotine']

# %%
# Count the frequency of each 'target_medicinal_product'
frequency = df_filtered['target_medicinal_product'].value_counts()

# Plotting the data
plt.figure(figsize=(10, 6))
frequency.plot(kind='bar', color='skyblue')

# Adding labels and title
plt.xlabel('Associated Drug')
plt.ylabel('Frequency')
plt.title('Frequency of Incident Reports for Pregnancy-Related Reactions Associated with Specific Drugs')

# Display the plot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# This bar graph illustrates the frequency of incident reports for pregnancy-related reactions associated with specific drugs in the drug API dataset.

# %%
# SQL query to select the required columns: census_region, death_rate, number_one_drug_used, and condition
query = """
SELECT census_region, death_rate, number_one_drug_used, condition
FROM result_table
"""

# Execute the query and load the data into a DataFrame
result_df = pd.read_sql(query, conn)


# Display the result
print(result_df)
# Out:
#                  census_region          death_rate  \
# 0     census region 2: midwest               10.15
# 1       census region 3: south                8.37
# 2        census region 4: west                6.89
# 3     census region 2: midwest   8.87 (unreliable)
# 4       census region 3: south               14.02
# 5        census region 4: west                7.93
# 6   census region 1: northeast                2.54
# 7     census region 2: midwest                4.21
# 8       census region 3: south                4.39
# 9        census region 4: west                3.36
# 10  census region 1: northeast                4.54
# 11    census region 2: midwest                6.01
# 12      census region 3: south                6.51
# 13       census region 4: west                4.74
# 14  census region 1: northeast  15.61 (unreliable)
# 15    census region 2: midwest               17.15
# 16      census region 3: south               13.01
# 17       census region 4: west   8.03 (unreliable)
# 18      census region 3: south  10.20 (unreliable)
# 19  census region 1: northeast                8.71
# 20    census region 2: midwest               12.90
# 21      census region 3: south               11.25
# 22       census region 4: west               10.18
# 23  census region 1: northeast                9.12
# 24    census region 2: midwest               10.91
# 25      census region 3: south               12.45
# 26       census region 4: west                9.69
# 27  census region 1: northeast                7.31
# 28    census region 2: midwest               10.68
# 29      census region 3: south               10.36
# 30       census region 4: west                9.42
# 31  census region 1: northeast               10.56
# 32    census region 2: midwest               13.33
# 33      census region 3: south               14.58
# 34       census region 4: west               10.43
# 35  census region 1: northeast  13.30 (unreliable)
# 36    census region 2: midwest               10.37
# 37      census region 3: south               13.07
# 38       census region 4: west               14.02
# 39  census region 1: northeast               11.77
# 40    census region 2: midwest               11.96
# 41      census region 3: south               12.99
# 42       census region 4: west               10.21
#
#                 number_one_drug_used                   condition
# 0                       azithromycin                   chlamydia
# 1                       azithromycin                   chlamydia
# 2                       azithromycin                   chlamydia
# 3                  magnesium sulfate                   eclampsia
# 4                  magnesium sulfate                   eclampsia
# 5                  magnesium sulfate                   eclampsia
# 6                            insulin        gestational_diabetes
# 7                            insulin        gestational_diabetes
# 8                            insulin        gestational_diabetes
# 9                            insulin        gestational_diabetes
# 10                         labetalol    gestational_hypertension
# 11                         labetalol    gestational_hypertension
# 12                         labetalol    gestational_hypertension
# 13                         labetalol    gestational_hypertension
# 14                       ceftriaxone                   gonorrhea
# 15                       ceftriaxone                   gonorrhea
# 16                       ceftriaxone                   gonorrhea
# 17                       ceftriaxone                   gonorrhea
# 18                        lamivudine                 hepatitis_b
# 19  avoid treatment during pregnancy                 hepatitis_c
# 20  avoid treatment during pregnancy                 hepatitis_c
# 21  avoid treatment during pregnancy                 hepatitis_c
# 22  avoid treatment during pregnancy                 hepatitis_c
# 23                           insulin      pre_pregnancy_diabetes
# 24                           insulin      pre_pregnancy_diabetes
# 25                           insulin      pre_pregnancy_diabetes
# 26                           insulin      pre_pregnancy_diabetes
# 27                         labetalol  pre_pregnancy_hypertension
# 28                         labetalol  pre_pregnancy_hypertension
# 29                         labetalol  pre_pregnancy_hypertension
# 30                         labetalol  pre_pregnancy_hypertension
# 31                     progesterone       previous_preterm_birth
# 32                     progesterone       previous_preterm_birth
# 33                     progesterone       previous_preterm_birth
# 34                     progesterone       previous_preterm_birth
# 35                      penicillin g                    syphilis
# 36                      penicillin g                    syphilis
# 37                      penicillin g                    syphilis
# 38                      penicillin g                    syphilis
# 39                          nicotine                    nicotine
# 40                          nicotine                    nicotine
# 41                          nicotine                    nicotine
# 42                          nicotine                    nicotine

# %%
# Convert 'death_rate' to numeric, forcing errors to NaN
result_df['death_rate'] = pd.to_numeric(result_df['death_rate'], errors='coerce')

# Exclude 'Avoid treatment during pregnancy' from the data
result_df = result_df[result_df['number_one_drug_used'] != 'avoid treatment during pregnancy']

# Group by 'number_one_drug_used' and calculate the average death_rate for each drug
avg_death_rate = result_df.groupby('number_one_drug_used')['death_rate'].mean().reset_index()

# Sort the data by death rate for better visualization 
avg_death_rate = avg_death_rate.sort_values('death_rate', ascending=False)

# Plotting the average death rates for each drug
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.bar(avg_death_rate['number_one_drug_used'], avg_death_rate['death_rate'], color='skyblue')
plt.xlabel('Number One Drug Used')
plt.ylabel('Average Death Rate (%)')
plt.title('Average Death Rates for Each Number One Drug Used To Treat the Pregnancy Condition Associated in the Natality Data')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to avoid label cutoff
plt.show()

# %% [markdown]
# This data is from a combination of two data tables. Unfortunately, drug names are not present in the natality data, limiting direct insights into the specific medications used during pregnancy.  By examining these factors, we aim to understand how they may correlate with birth outcomes. To provide context, the number one drug used to treat the conditions studied was researched and incorporated into the analysis. However, it is important to note that there is no direct evidence of drug usage during pregnancy within the natality dataset itself. The results correlate with the assumption that the drugs were used to treat the conditions found in the natality data.

# %%
import seaborn as sns

# Exclude 'Avoid treatment during pregnancy' from the data
filtered_df = result_df[result_df['number_one_drug_used'] != 'avoid treatment during pregnancy']

# Group by 'number_one_drug_used' and 'census_region' to calculate average death rate
avg_death_rate_by_region = filtered_df.groupby(['number_one_drug_used', 'census_region'])['death_rate'].mean().reset_index()

# Create a pivot table for easier plotting
pivot_df = avg_death_rate_by_region.pivot(index='number_one_drug_used', columns='census_region', values='death_rate')

# Plotting
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_df, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Average Death Rates for Each Number One Drug Used by Census Region', fontsize=16)
plt.ylabel('Drug Used')
plt.xlabel('Census Region')
# Add a disclaimer text at the bottom
plt.figtext(0.5, -0.1, 
            'Disclaimer: Drug use and average death rates cannot be assumed to be linked. The observed data could be influenced by the nature of the condition during pregnancy, as per the natality data.',
            wrap=True, horizontalalignment='center', fontsize=10, color='gray')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Check the unique values in both 'target_medicinal_product' and 'number_one_drug_used'
print("Unique values in frequency['target_medicinal_product']:")
print(frequency['target_medicinal_product'].unique())

print("Unique values in avg_death_rate['number_one_drug_used']:")
print(avg_death_rate['number_one_drug_used'].unique())

# Normalize both columns
frequency['target_medicinal_product'] = frequency['target_medicinal_product'].str.strip().str.lower()
avg_death_rate['number_one_drug_used'] = avg_death_rate['number_one_drug_used'].str.strip().str.lower()

# Check for the presence of 'progesterone' specifically after normalization
print("Checking if 'progesterone' is in both dataframes after normalization:")
print("Progesterone in frequency:", "progesterone" in frequency['target_medicinal_product'].values)
print("Progesterone in avg_death_rate:", "progesterone" in avg_death_rate['number_one_drug_used'].values)

# Calculate frequency of 'target_medicinal_product'
frequency = df_filtered['target_medicinal_product'].value_counts().reset_index()
frequency.columns = ['target_medicinal_product', 'frequency']

# Calculate mean death rate using group by with 'number_one_drug_used'
avg_death_rate = result_df.groupby('number_one_drug_used')['death_rate'].mean().reset_index()
avg_death_rate.columns = ['number_one_drug_used', 'death_rate']

# Merge frequency data with the death rate data using different column names
merged_df = pd.merge(
    frequency,
    avg_death_rate,
    left_on='target_medicinal_product',
    right_on='number_one_drug_used',
    how='left'
)

# Check if 'progesterone' is in the merged dataframe
print("Checking if 'progesterone' is in the merged dataframe:")
print(merged_df[merged_df['target_medicinal_product'] == 'progesterone'])

# Plotting the comparison (scatter plot of frequency vs death rate)
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['frequency'], merged_df['death_rate'], color='purple', s=100)  # Adjust size 's' as needed
plt.xlabel('Frequency of Reported Pregnancy Reaction in Drug API')
plt.ylabel('Average Death Rate (%)')
plt.title('Comparison of Reported Pregnancy Reaction Drug API vs. Death Rate')

# Annotate each point with the 'target_medicinal_product' name
for i, txt in enumerate(merged_df['target_medicinal_product']):
    plt.annotate(txt, (merged_df['frequency'][i], merged_df['death_rate'][i]), fontsize=9, ha='right')

plt.tight_layout()
plt.show()
# Out:
# Unique values in frequency['target_medicinal_product']:
# ['ceftriaxone' 'insulin' 'labetalol' 'nicotine' 'progesterone'
#  'azithromycin' 'penicillin g' 'magnesium sulfate' 'lamivudine']
# Unique values in avg_death_rate['number_one_drug_used']:
# ['azithromycin' 'ceftriaxone' 'insulin' 'labetalol' 'lamivudine'
#  'magnesium sulfate' 'nicotine' 'penicillin g' 'progesterone ']
# Checking if 'progesterone' is in both dataframes after normalization:
# Progesterone in frequency: True
# Progesterone in avg_death_rate: True
# Checking if 'progesterone' is in the merged dataframe:
#   target_medicinal_product  frequency number_one_drug_used  death_rate
# 4             progesterone          3         progesterone      12.225

# %% [markdown]
# Overall, the reported drug reactions during pregnancy in the drug API dataset appear to be relatively low, and do not seem to align with the death rates observed in newborns within the natality data. This suggests that factors beyond the drug itself may contribute to the outcomes.

# %%
print(result_df['number_one_drug_used'].unique())
# Out:
# ['azithromycin' 'magnesium sulfate' 'insulin' 'labetalol' 'ceftriaxone'
#  'lamivudine' 'progesterone ' 'penicillin g' 'nicotine']

# %%
# Strip any leading or trailing spaces in the 'number_one_drug_used' column
result_df['number_one_drug_used'] = result_df['number_one_drug_used'].str.strip()

# check if 'progesterone' is normalized correctly
print("Progesterone in result_df:", "progesterone" in result_df['number_one_drug_used'].values)
# Out:
# Progesterone in result_df: True

# %%
import pandas as pd

# Adjust display options to show all columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.width', None)     # Adjust width to avoid truncation
pd.set_option('display.max_colwidth', None)  # Ensure no column content is truncated

# Print the entire merged DataFrame
print(merged_df)
# Out:
#   target_medicinal_product  frequency number_one_drug_used  death_rate
# 0              ceftriaxone          5          ceftriaxone   15.080000
# 1                  insulin          4              insulin    7.083750
# 2                labetalol          4            labetalol    7.446250
# 3                 nicotine          4             nicotine   11.732500
# 4             progesterone          3                  NaN         NaN
# 5             azithromycin          3         azithromycin    8.470000
# 6             penicillin g          2         penicillin g   12.486667
# 7        magnesium sulfate          1    magnesium sulfate   10.975000
# 8               lamivudine          1           lamivudine         NaN

# %%
# Filter for rows with 'progesterone' in the 'number_one_drug_used' column
progesterone_rows = result_df[result_df['number_one_drug_used'].str.contains('progesterone', na=False, case=False)]

# Display rows for validation
print("Rows in 'result_df' with 'progesterone':")
print(progesterone_rows)

# Calculate the average death rate for 'progesterone'
average_death_rate_progesterone = progesterone_rows['death_rate'].mean()
print(f"\nAverage Death Rate for 'progesterone': {average_death_rate_progesterone:.4f}")
# Out:
# Rows in 'result_df' with 'progesterone':
#                  census_region  death_rate number_one_drug_used  \
# 31  census region 1: northeast       10.56        progesterone
# 32    census region 2: midwest       13.33        progesterone
# 33      census region 3: south       14.58        progesterone
# 34       census region 4: west       10.43        progesterone
#
#                  condition normalized_drug
# 31  previous_preterm_birth    progesterone
# 32  previous_preterm_birth    progesterone
# 33  previous_preterm_birth    progesterone
# 34  previous_preterm_birth    progesterone
#
# Average Death Rate for 'progesterone': 12.2250

# %%
print("Unique target_medicinal_product values:")
print(frequency['target_medicinal_product'].unique())

print("\nUnique number_one_drug_used values:")
print(avg_death_rate['number_one_drug_used'].unique())
# Out:
# Unique target_medicinal_product values:
# ['ceftriaxone' 'insulin' 'labetalol' 'nicotine' 'progesterone'
#  'azithromycin' 'penicillin g' 'magnesium sulfate' 'lamivudine']
#
# Unique number_one_drug_used values:
# ['azithromycin' 'ceftriaxone' 'insulin' 'labetalol' 'lamivudine'
#  'magnesium sulfate' 'nicotine' 'penicillin g' 'progesterone ']

# %%
# Query to get column names for 'result_table'
query = "PRAGMA table_info(table3);"
column_info = pd.read_sql_query(query, conn)

# Display the column names and their details
column_info
# Out:
#    cid                            name     type  notnull dflt_value  pk
# 0    0                       report_id  INTEGER        0       None   0
# 1    1                     patient_age     REAL        0       None   0
# 2    2                     patient_sex     REAL        0       None   0
# 3    3                  patient_weight     REAL        0       None   0
# 4    4                 drug_indication     TEXT        0       None   0
# 5    5  seriousness_congenital_anomaly     REAL        0       None   0
# 6    6        target_medicinal_product     TEXT        0       None   0
# 7    7         other_medicinal_product     TEXT        0       None   0
# 8    8        pregnancy_reaction_event     TEXT        0       None   0
# 9    9            other_reaction_event     TEXT        0       None   0

# %%
# Query data from table3

# Connect to (or create) an SQLite database
conn = sqlite3.connect("pregnancy_database.db")
                       
query = query = "SELECT * FROM table3"
df = pd.read_sql(query, conn)

# List of valid options
valid_options = [
    'azithromycin', 'magnesium sulfate', 'insulin', 'labetalol', 
    'ceftriaxone', 'lamivudine', 'progesterone', 'penicillin g', 'nicotine'
]

# Filter the DataFrame to only include the valid options
df_filtered2 = df[df['target_medicinal_product'].isin(valid_options)]

# Clean the 'target_medicinal_product' values if needed using .loc to avoid the warning
df_filtered2.loc[:, 'target_medicinal_product'] = df_filtered['target_medicinal_product'].replace({
    'insulin glargine': 'insulin',
    'labetalol, labetalol': 'labetalol',
    'magnesium sulfate.': 'magnesium sulfate',
    'progesterone.': 'progesterone',
    'progesterone (solution)': 'progesterone',
    'penicillin g potassium injection': 'penicillin g',
    'penicillin g potassium injection, penicillin g...': 'penicillin g',
    'azithromycin, azithromycin, lamivudine, lamivudine': 'azithromycin',
    'ceftriaxone injection, azithromycin': 'ceftriaxone',
    'lamivudine-hiv': 'lamivudine',
    'lamivudine and zidovudine': 'lamivudine',
    'nicotine (none)': 'nicotine'
})


# write the filtered DataFrame back to a new table in the SQLite database
df_filtered2.to_sql('filtered_table3', conn, if_exists='replace', index=False)

# Display the filtered data
print(df_filtered2)
# Out:
#     report_id  patient_age  patient_sex  patient_weight  \
# 0    10009044          1.0          1.0            4.00
# 1    10016807          NaN          0.0             NaN
# 2    10019262          NaN          2.0            2.54
# 4    10038823          0.0          2.0            3.60
# 5    10017067          NaN          2.0          108.96
# 7    10027954         33.0          2.0             NaN
# 8    10047438         39.0          2.0             NaN
# 9    10051068         28.0          2.0             NaN
# 10   10056773          NaN          2.0             NaN
# 16   10072649         32.0          2.0             NaN
# 17   10144772         42.0          2.0           61.00
# 18   10227619         32.0          2.0             NaN
# 20   10003326         29.0          2.0             NaN
# 21   10003424         30.0          2.0             NaN
# 22   10003428          NaN          2.0             NaN
# 23   10003429         28.0          2.0             NaN
# 24   10003449         32.0          2.0             NaN
# 25   10222287         19.0          2.0             NaN
# 29   10440328          1.0          1.0            2.50
# 31   10056932          NaN          1.0             NaN
# 32   10059489          NaN          1.0            2.60
# 34   10079120          NaN          2.0            3.20
# 37   10012212          NaN          2.0             NaN
# 39   10010087         28.0          2.0             NaN
# 40   10010162         33.0          2.0             NaN
# 42   10024207         30.0          2.0             NaN
# 43   10024410          NaN          1.0             NaN
#
#                                       drug_indication  \
# 0   hypertension, hypertension, gestational diabet...
# 1                                                None
# 2                                gestational diabetes
# 4   hiv infection, hiv infection, diabetes mellitu...
# 5   renal transplant, renal transplant, renal tran...
# 7                         pre-eclampsia, hypertension
# 8                                       contraception
# 9   labour induction, asthma, asthma, gestational ...
# 10                                               None
# 16                                               None
# 17           pulmonary embolism, pregnancy, pregnancy
# 18                             assisted fertilisation
# 20                           listeriosis, listeriosis
# 21                           listeriosis, listeriosis
# 22                                               None
# 23              listeriosis, listeriosis, listeriosis
# 24  listeriosis, listeriosis, listeriosis, listeri...
# 25  product used for unknown indication, product u...
# 29  product used for unknown indication, product u...
# 31                                               None
# 32       postpartum depression, postpartum depression
# 34                depression, mineral supplementation
# 37  maternal exposure timing unspecified, maternal...
# 39               drug dependence, nicotine dependence
# 40  drug dependence, product used for unknown indi...
# 42                   drug dependence, drug dependence
# 43  drug dependence, drug dependence, product used...
#
#     seriousness_congenital_anomaly target_medicinal_product  \
# 0                              1.0                  insulin
# 1                              NaN                  insulin
# 2                              1.0                  insulin
# 4                              1.0                  insulin
# 5                              NaN                labetalol
# 7                              NaN                labetalol
# 8                              NaN                labetalol
# 9                              NaN                labetalol
# 10                             NaN        magnesium sulfate
# 16                             NaN             progesterone
# 17                             NaN             progesterone
# 18                             NaN             progesterone
# 20                             NaN              ceftriaxone
# 21                             NaN              ceftriaxone
# 22                             NaN              ceftriaxone
# 23                             NaN              ceftriaxone
# 24                             NaN              ceftriaxone
# 25                             NaN             penicillin g
# 29                             1.0             penicillin g
# 31                             1.0             azithromycin
# 32                             1.0             azithromycin
# 34                             1.0             azithromycin
# 37                             1.0               lamivudine
# 39                             NaN                 nicotine
# 40                             NaN                 nicotine
# 42                             NaN                 nicotine
# 43                             NaN                 nicotine
#
#                               other_medicinal_product  \
# 0   metoprolol (unknown), bisoprolol, folio, dopeg...
# 1   hydralazine, methyldopa, telmisartan, amlodipi...
# 2                        effexor, zyprexa, levothyrox
# 4   combivir, kaletra, metformin, nexium, prenatal...
# 5   mycophenolate mofetil, calcitriol, azathioprin...
# 7                              nifedipine, nifedipine
# 8   hydrochlorothiazide., triamcinolone, tylenol, ...
# 9   oxytocin, salbutamol, fluticasone, calcium, fe...
# 10                   heparin, ritodrine hydrochloride
# 16  armour thyroid, procardia, lovenox, aspirin, c...
# 17                     lovenox, estradiol, folic acid
# 18                    bravelle, decapeptyl /00957902/
# 20                                      metronidazole
# 21                                      metronidazole
# 22                         metronidazole, amoxicillin
# 23                         metronidazole, amoxicillin
# 24  clarithromycin, amoxicillin+clavulanate, cefme...
# 25  ranitidine, entonox, paracetamol, piriton, lev...
# 29  augmentin, effexor, venlafaxine hydrochloride ...
# 31  effexor, amox-clav, effexor, venlafaxine hcl, ...
# 32  venlafaxine, nitrofur mac, metronidazole., zan...
# 34  wellbutrin, wellbutrin xl, clarinex, naproxen....
# 37                                  kaletra, abacavir
# 39                              buprenorphine generic
# 40  suboxone film, alcohol, prenatal vitamins, zol...
# 42                   suboxone, subutex 8 mg, vitamins
# 43  suboxone 8 mg, buprenorphine 8 mg (none), unsp...
#
#                              pregnancy_reaction_event  \
# 0                    foetal exposure during pregnancy
# 1   foetal death, foetal heart rate deceleration a...
# 2                    foetal exposure during pregnancy
# 4                    foetal exposure during pregnancy
# 5    maternal exposure during pregnancy, foetal death
# 7       premature delivery, exposure during pregnancy
# 8   premature delivery, pregnancy with contracepti...
# 9                  maternal exposure during pregnancy
# 10                   foetal exposure during pregnancy
# 16  foetal growth restriction, exposure during pre...
# 17                          exposure during pregnancy
# 18                                  ectopic pregnancy
# 20                 maternal exposure during pregnancy
# 21   foetal death, maternal exposure during pregnancy
# 22  foetal distress syndrome, foetal exposure duri...
# 23                 maternal exposure during pregnancy
# 24                 maternal exposure during pregnancy
# 25                          exposure during pregnancy
# 29                   foetal exposure during pregnancy
# 31                 maternal exposure during pregnancy
# 32                 maternal exposure during pregnancy
# 34  maternal exposure during pregnancy, persistent...
# 37  foetal growth restriction, foetal exposure dur...
# 39                 maternal exposure during pregnancy
# 40                 maternal exposure during pregnancy
# 42                          exposure during pregnancy
# 43                   foetal exposure during pregnancy
#
#                                  other_reaction_event
# 0        congenital hydronephrosis, ureteric stenosis
# 1                                      premature baby
# 2                   multiple congenital abnormalities
# 4   ventricular septal defect, atrial septal defec...
# 5                                                None
# 7   hypertension, proteinuria, umbilical cord vasc...
# 8   injury, device breakage, uterine perforation, ...
# 9   hypertension, renal failure chronic, condition...
# 10          premature baby, apgar score low, acidosis
# 16               oligohydramnios, breech presentation
# 17                                         thrombosis
# 18                                               None
# 20          meconium stain, amniotic cavity infection
# 21           abortion late, amniotic cavity infection
# 22  intraventricular haemorrhage neonatal, low bir...
# 23          meconium stain, amniotic cavity infection
# 24                     pyelonephritis, normal newborn
# 25             angioedema, enlarged uvula, live birth
# 29  double outlet right ventricle, pulmonary arter...
# 31                                        anencephaly
# 32  congenital anomaly, meningomyelocele, talipes,...
# 34  patent ductus arteriosus, tricuspid valve inco...
# 37  premature baby, acute hepatic failure, renal f...
# 39  wrong technique in drug usage process, abortio...
# 40               alcohol abuse, intentional underdose
# 42                                 selective abortion
# 43                  drug withdrawal syndrome neonatal

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by 'target_medicinal_product' and 'pregnancy_reaction_event', count occurrences
reaction_summary = df_filtered.groupby(['target_medicinal_product', 'pregnancy_reaction_event']).size().reset_index(name='count')

# Pivot the data to create a table where each row is a reaction event and each column is a product
pivot_data = reaction_summary.pivot_table(index='pregnancy_reaction_event', columns='target_medicinal_product', values='count', aggfunc='sum', fill_value=0)

# Plot the horizontal stacked bar plot
pivot_data.plot(kind='barh', stacked=True, figsize=(12, 6))

# Rotate the y-axis labels for better readability
plt.yticks(rotation=0)

# Labels and title
plt.xlabel('Count')
plt.ylabel('Pregnancy Reaction Event')
plt.title('Pregnancy Reaction Events for Each Target Medicinal Product (Stacked)')

# Adjust the legend size (smaller)
plt.legend(title='Medicinal Product', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')  # Smaller font size

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %%
# Close connection
conn.close()

# %% [markdown]
# # Summary of Findings

# %% [markdown]
# This analysis examined the relationship between drug use during pregnancy and maternal and infant health outcomes by combining natality data, drug information from the OpenFDA API, and public data on pregnancy category drugs from Wikipedia. Several ethical considerations were addressed during the data transformation and analysis process. The data underwent significant transformations, particularly the merging of natality data with drug information from the OpenFDA API. This transformation involved inferring drug use based on pregnancy-related conditions, which could introduce biases or inaccuracies, especially in cases where treatments were not directly associated with specific conditions. The assumption that listed treatments were used for the conditions may not always hold true in every case.
#
# The main findings suggest that certain drugs are commonly linked to pregnancy-related conditions, such as insulin for gestational diabetes, labetalol for pre-pregnancy hypertension, and ceftriaxone for gonorrhea, based on the conditions identified in the data. It is important to note that while these drugs are often used to treat these conditions, the analysis does not confirm that they were specifically prescribed to the individuals. The study also noted regional variations in drug use and death rates, with ceftriaxone use more prevalent in the South, and nicotine use being common across all regions but associated with higher mortality in the South. The analysis further indicated that insulin was linked to the lowest death rate, which may reflect its role in managing conditions like gestational diabetes, while ceftriaxone was associated with higher death rates, possibly due to its use in more severe health situations. These observations provide insight into patterns of drug use during pregnancy in relation to maternal conditions, though further research is needed to better understand the complexities of these associations and their potential implications.
#
# The data used in this analysis was publicly available, and no individual-level data was included, reducing privacy concerns. Adherence to privacy laws such as HIPAA (Health Insurance Portability and Accountability Act) was necessary during the data extraction process to protect individuals' privacy and ensure data security. It is important to note the primary risk introduced during data transformation in this analysis.  By inferring drug use from pregnancy conditions, the analysis could lead to potentially misleading correlations, that imply causality between drug use and adverse pregnancy outcomes, which is not supported by the data.  These assumptions in the cleaning and transformation process could greatly affect the accuracy.
#
# The natality data was sourced from the CDC which is a credible public health organization, and the drug data was sourced from the OpenFDA API.  Both are government databases, with high levels of regulation, which posed as a difficult barrier in the analysis at times.  To mitigate potential ethical risks, proper documentation of assumptions and the data cleaning and transformations were heavily documented.  The analysis requires further research in order to find a mroe reliable cause-and-effect relationship.
